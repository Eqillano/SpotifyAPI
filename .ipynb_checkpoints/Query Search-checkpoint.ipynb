# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

client_id = '6f511f76a1e44dcdb8c740dc527d497d'
client_secret = '908a52d2d6eb4d01b84ed47ff3a2319d'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
   
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
           raise Exception('You must provide a valid key')

        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {"Authorization": f'Basic {client_creds_b64}'}
        
        
    def get_token_data(self):
        return {'grant_type':"client_credentials"}
        
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url,data=token_data,headers=token_headers)
        if r.status_code not in range(200,299):
           print(r.json())
           return False

        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token 
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
           self.perform_auth()
           return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
    "Authorization": f"Bearer {access_token}"}
        return headers
        
    
    
    def get_resource(self,lookup_id,resource_type='albums'):
        endpoint = f"https://api.spotify.com/v1/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
           return {}
        return r.json()
    
    def get_album(self,_id):
        return self.get_resource(_id,resource_type='albums')
        
    
    def get_artist(self,_id):
        return self.get_resource(_id,resource_type='artists')
    
    
    def base_search(self,query_params):
        headers = self.get_resource_header()
        endpoint ='https://api.spotify.com/v1/search'
        #data = urlencode({"q":query_params,"type":search_type.lower()}) 
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url,headers=headers)
        if r.status_code not in range(200,299):
           return {}
        return r.json()
    
    def search(self,query=None,operator=None,operator_query=None,search_type='artist'):
        if query == None:
           raise Exception ('A query is required')
        if isinstance(query,dict):
           query = " ".join({f'{k},{v}' for k,v in query.items()})
        query_params = urlencode({"q":query,"type":search_type.lower()}) 
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search({"track": "Time"},search_type='track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%2CTime&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3FEd0qHPFOgcpfw7bCXB4x'},
#        'href': 'https://api.spotify.com/v1/artists/3FEd0qHPFOgcpfw7bCXB4x',
#        'id': '3FEd0qHPFOgcpfw7bCXB4x',
#        'name': 'Zubin Mehta',
#        'type': 'artist',
#        'uri': 'spotify:artist:3FEd0qHPFOgcpfw7bCXB4x'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EQvBmWlfyaRLGDuVfKmve'},
#        'href': 'https://api.spotify.com/v1/artists/3EQvBmWlfyaRLGDuVfKmve',
#        'id': '3EQvBmWlfyaRLGDuVfKmve',
#        'name': 'Lorin Maazel',
#        'type': 'artist',
#        'uri': 'spotify:artist:3EQvBmWlfyaRLGDuVfKmve'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aL4ovuNuBg7rmrPjOTIUN'},
#        'href': 'https://api.spotify.com/v1/artists/6aL4ovuNuBg7rmrPjOTIUN',
#        'id': '6aL4ovuNuBg7rmrPjOTIUN',
#        'name': 'Carlos Kleiber',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aL4ovuNuBg7rmrPjOTIUN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5zCaQxjl110XTrm4LQ1CxY'},
#        'href': 'https://api.spotify.com/v1/artists/5zCaQxjl110XTrm4LQ1CxY',
#        'id': '5zCaQxjl110XTrm4LQ1CxY',
#        'name': 'Herbert von Karajan',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zCaQxjl110XTrm4LQ1CxY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Uk6VYJIgV8zfp3uNFX2Fy'},
#      'href': 'https://api.spotify.com/v1/albums/6Uk6VYJIgV8zfp3uNFX2Fy',
#      'id': '6Uk6VYJIgV8zfp3uNFX2Fy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731acd39ed2d8302c30ee0a0b6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021acd39ed2d8302c30ee0a0b6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511acd39ed2d8302c30ee0a0b6',
#        'width': 64}],
#      'name': "Legendary Moments of the New Year's Concert",
#      'release_date': '1989',
#      'release_date_precision': 'year',
#      'total_tracks': 39,
#      'type': 'album',
#      'uri': 'spotify:album:6Uk6VYJIgV8zfp3uNFX2Fy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5goS0v24Fc1ydjCKQRwtjM'},
#       'href': 'https://api.spotify.com/v1/artists/5goS0v24Fc1ydjCKQRwtjM',
#       'id': '5goS0v24Fc1ydjCKQRwtjM',
#       'name': 'Johann Strauss II',
#       'type': 'artist',
#       'uri': 'spotify:artist:5goS0v24Fc1ydjCKQRwtjM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/003f4bk13c6Q3gAUXv7dGJ'},
#       'href': 'https://api.spotify.com/v1/artists/003f4bk13c6Q3gAUXv7dGJ',
#       'id': '003f4bk13c6Q3gAUXv7dGJ',
#       'name': 'Wiener Philharmoniker',
#       'type': 'artist',
#       'uri': 'spotify:artist:003f4bk13c6Q3gAUXv7dGJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aL4ovuNuBg7rmrPjOTIUN'},
#       'href': 'https://api.spotify.com/v1/artists/6aL4ovuNuBg7rmrPjOTIUN',
#       'id': '6aL4ovuNuBg7rmrPjOTIUN',
#       'name': 'Carlos Kleiber',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aL4ovuNuBg7rmrPjOTIUN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 3,
#     'duration_ms': 183546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11103747'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/496yGrNkbRPpaJcqKy54Lj'},
#     'href': 'https://api.spotify.com/v1/tracks/496yGrNkbRPpaJcqKy54Lj',
#     'id': '496yGrNkbRPpaJcqKy54Lj',
#     'is_local': False,
#     'name': 'Bauern-Polka, Op. 276 - track time includes applause',
#     'popularity': 17,
#     'preview_url': 'https://p.scdn.co/mp3-preview/262517c4318965851475e1aca83c7995ff8bde9b?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:496yGrNkbRPpaJcqKy54Lj'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eBDae8nEzoq5GThrBTpRP'},
#        'href': 'https://api.spotify.com/v1/artists/7eBDae8nEzoq5GThrBTpRP',
#        'id': '7eBDae8nEzoq5GThrBTpRP',
#        'name': 'MTNS',
#        'type': 'artist',
#        'uri': 'spotify:artist:7eBDae8nEzoq5GThrBTpRP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5kAHu3wACpQpUzbGUFktPO'},
#      'href': 'https://api.spotify.com/v1/albums/5kAHu3wACpQpUzbGUFktPO',
#      'id': '5kAHu3wACpQpUzbGUFktPO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735f8eea8575e2440f1383c9f1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025f8eea8575e2440f1383c9f1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515f8eea8575e2440f1383c9f1',
#        'width': 64}],
#      'name': 'Salvage',
#      'release_date': '2013-11-22',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:5kAHu3wACpQpUzbGUFktPO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eBDae8nEzoq5GThrBTpRP'},
#       'href': 'https://api.spotify.com/v1/artists/7eBDae8nEzoq5GThrBTpRP',
#       'id': '7eBDae8nEzoq5GThrBTpRP',
#       'name': 'MTNS',
#       'type': 'artist',
#       'uri': 'spotify:artist:7eBDae8nEzoq5GThrBTpRP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176375,
#     'explicit': False,
#     'external_ids': {'isrc': 'AU5Q11300058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4xc6zhOuNEnMM9gXUKhd8T'},
#     'href': 'https://api.spotify.com/v1/tracks/4xc6zhOuNEnMM9gXUKhd8T',
#     'id': '4xc6zhOuNEnMM9gXUKhd8T',
#     'is_local': False,
#     'name': 'Lost Track of Time',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9180e86fd05b3a1342ca7c0288f98aa1e1a315de?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4xc6zhOuNEnMM9gXUKhd8T'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CvCyf1gEVhI0mX6aFXmVI'},
#        'href': 'https://api.spotify.com/v1/artists/2CvCyf1gEVhI0mX6aFXmVI',
#        'id': '2CvCyf1gEVhI0mX6aFXmVI',
#        'name': 'Paul Simon',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CvCyf1gEVhI0mX6aFXmVI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/08tZq3FDsspdU6ycn8Jl2o'},
#      'href': 'https://api.spotify.com/v1/albums/08tZq3FDsspdU6ycn8Jl2o',
#      'id': '08tZq3FDsspdU6ycn8Jl2o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cda9f2947d87161a48effb2c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cda9f2947d87161a48effb2c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cda9f2947d87161a48effb2c',
#        'width': 64}],
#      'name': 'The Rhythm Of The Saints',
#      'release_date': '1990-10-16',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:08tZq3FDsspdU6ycn8Jl2o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CvCyf1gEVhI0mX6aFXmVI'},
#       'href': 'https://api.spotify.com/v1/artists/2CvCyf1gEVhI0mX6aFXmVI',
#       'id': '2CvCyf1gEVhI0mX6aFXmVI',
#       'name': 'Paul Simon',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CvCyf1gEVhI0mX6aFXmVI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230226,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11002351'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/09f7w8W30zPHY5e48omn4K'},
#     'href': 'https://api.spotify.com/v1/tracks/09f7w8W30zPHY5e48omn4K',
#     'id': '09f7w8W30zPHY5e48omn4K',
#     'is_local': False,
#     'name': 'Born at the Right Time (Original Acoustic Demo) - Bonus Track',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dc662dfc527713882d15e5a2c3688b8a5d9cb803?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:09f7w8W30zPHY5e48omn4K'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 374893,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ofi9goaZUnwcWvdSPYcYX'},
#     'href': 'https://api.spotify.com/v1/tracks/4ofi9goaZUnwcWvdSPYcYX',
#     'id': '4ofi9goaZUnwcWvdSPYcYX',
#     'is_local': False,
#     'name': 'Untethered Angel',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71e9d36c705d3fbac6deb60d17c61b1d452e8c0b?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ofi9goaZUnwcWvdSPYcYX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 257800,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906502'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7DCLX6EC3qcwW9Cz38DJ8O'},
#     'href': 'https://api.spotify.com/v1/tracks/7DCLX6EC3qcwW9Cz38DJ8O',
#     'id': '7DCLX6EC3qcwW9Cz38DJ8O',
#     'is_local': False,
#     'name': 'Paralyzed',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9e6e82078006dcf0f2d6fa857672c7422880a892?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7DCLX6EC3qcwW9Cz38DJ8O'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 424520,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906503'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/02YXYTdPKzfYhAhMjiOEK9'},
#     'href': 'https://api.spotify.com/v1/tracks/02YXYTdPKzfYhAhMjiOEK9',
#     'id': '02YXYTdPKzfYhAhMjiOEK9',
#     'is_local': False,
#     'name': 'Fall into the Light',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/55814aeb688bb3863c7b1a20ba9dd53c43c22516?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:02YXYTdPKzfYhAhMjiOEK9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tilLfGf17NFKXv7T9OVnh'},
#        'href': 'https://api.spotify.com/v1/artists/3tilLfGf17NFKXv7T9OVnh',
#        'id': '3tilLfGf17NFKXv7T9OVnh',
#        'name': 'Crim Dela Crim',
#        'type': 'artist',
#        'uri': 'spotify:artist:3tilLfGf17NFKXv7T9OVnh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XH8MIrNd65yTMWg8TcuQ9'},
#      'href': 'https://api.spotify.com/v1/albums/6XH8MIrNd65yTMWg8TcuQ9',
#      'id': '6XH8MIrNd65yTMWg8TcuQ9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aaec7e02c7013ab69a24db49',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aaec7e02c7013ab69a24db49',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aaec7e02c7013ab69a24db49',
#        'width': 64}],
#      'name': "Who's Crim Dela Crim?",
#      'release_date': '2019-04-05',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6XH8MIrNd65yTMWg8TcuQ9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tilLfGf17NFKXv7T9OVnh'},
#       'href': 'https://api.spotify.com/v1/artists/3tilLfGf17NFKXv7T9OVnh',
#       'id': '3tilLfGf17NFKXv7T9OVnh',
#       'name': 'Crim Dela Crim',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tilLfGf17NFKXv7T9OVnh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5icKdCmMhNMYoAzVBAWt39'},
#       'href': 'https://api.spotify.com/v1/artists/5icKdCmMhNMYoAzVBAWt39',
#       'id': '5icKdCmMhNMYoAzVBAWt39',
#       'name': 'Dax',
#       'type': 'artist',
#       'uri': 'spotify:artist:5icKdCmMhNMYoAzVBAWt39'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172564,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM24S1910429'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7i1R7Eg6LgIIEfi3ofZydA'},
#     'href': 'https://api.spotify.com/v1/tracks/7i1R7Eg6LgIIEfi3ofZydA',
#     'id': '7i1R7Eg6LgIIEfi3ofZydA',
#     'is_local': False,
#     'name': 'Time (Bonus Track)',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/62da8b9572fd952683b83084c533ae4f47b674e7?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7i1R7Eg6LgIIEfi3ofZydA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 403413,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906504'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dQHtmVxm44ctQOIovPP8w'},
#     'href': 'https://api.spotify.com/v1/tracks/3dQHtmVxm44ctQOIovPP8w',
#     'id': '3dQHtmVxm44ctQOIovPP8w',
#     'is_local': False,
#     'name': 'Barstool Warrior',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5280bd1d339f6059fafd3f498221227db821a5cd?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3dQHtmVxm44ctQOIovPP8w'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 560853,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906507'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1eoHEohApA5EuLcqhbO2FF'},
#     'href': 'https://api.spotify.com/v1/tracks/1eoHEohApA5EuLcqhbO2FF',
#     'id': '1eoHEohApA5EuLcqhbO2FF',
#     'is_local': False,
#     'name': "At Wit's End",
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/55cb682637b5a3448107ba8c1b89124c91db7bad?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1eoHEohApA5EuLcqhbO2FF'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QviryaneolcRmDB57SLco'},
#      'href': 'https://api.spotify.com/v1/albums/4QviryaneolcRmDB57SLco',
#      'id': '4QviryaneolcRmDB57SLco',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737bcc78f88610d99eaa8c9b50',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027bcc78f88610d99eaa8c9b50',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517bcc78f88610d99eaa8c9b50',
#        'width': 64}],
#      'name': 'The Rocky Horror Picture Show - Original Soundtrack',
#      'release_date': '1975-01-10',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:4QviryaneolcRmDB57SLco'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18RdrdlKkNsF7XRlu3MFsa'},
#       'href': 'https://api.spotify.com/v1/artists/18RdrdlKkNsF7XRlu3MFsa',
#       'id': '18RdrdlKkNsF7XRlu3MFsa',
#       'name': 'Cast',
#       'type': 'artist',
#       'uri': 'spotify:artist:18RdrdlKkNsF7XRlu3MFsa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 250984,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560854004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5aQ7o2lot4NiKDC60anRi5'},
#     'href': 'https://api.spotify.com/v1/tracks/5aQ7o2lot4NiKDC60anRi5',
#     'id': '5aQ7o2lot4NiKDC60anRi5',
#     'is_local': False,
#     'name': 'The Time Warp (Music - 1 - Background Track U Mix)',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b5de80fe5255f2270688034ccb15f7ccd03380f3?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:5aQ7o2lot4NiKDC60anRi5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/480xKab3lUPhBBnCzlzqIu'},
#        'href': 'https://api.spotify.com/v1/artists/480xKab3lUPhBBnCzlzqIu',
#        'id': '480xKab3lUPhBBnCzlzqIu',
#        'name': 'Taylor Davis',
#        'type': 'artist',
#        'uri': 'spotify:artist:480xKab3lUPhBBnCzlzqIu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5OLju6VznOPxJk5s62YS0k'},
#      'href': 'https://api.spotify.com/v1/albums/5OLju6VznOPxJk5s62YS0k',
#      'id': '5OLju6VznOPxJk5s62YS0k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732690ac0aac27332dbe7f9790',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022690ac0aac27332dbe7f9790',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512690ac0aac27332dbe7f9790',
#        'width': 64}],
#      'name': 'Melodies of Hyrule: Music from "The Legend of Zelda"',
#      'release_date': '2013-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5OLju6VznOPxJk5s62YS0k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/480xKab3lUPhBBnCzlzqIu'},
#       'href': 'https://api.spotify.com/v1/artists/480xKab3lUPhBBnCzlzqIu',
#       'id': '480xKab3lUPhBBnCzlzqIu',
#       'name': 'Taylor Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:480xKab3lUPhBBnCzlzqIu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 207320,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCABS1305252'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0YjENwOJIU54L9ypgBXadN'},
#     'href': 'https://api.spotify.com/v1/tracks/0YjENwOJIU54L9ypgBXadN',
#     'id': '0YjENwOJIU54L9ypgBXadN',
#     'is_local': False,
#     'name': 'Lost Woods (From "Ocarina of Time") [Bonus Track]',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/84a5c4ac722c358ef73cd8f6ac749486033a0882?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:0YjENwOJIU54L9ypgBXadN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
# ...
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244626,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906508'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Xxjyrl6Z8BtyY7EBBwozI'},
#     'href': 'https://api.spotify.com/v1/tracks/0Xxjyrl6Z8BtyY7EBBwozI',
#     'id': '0Xxjyrl6Z8BtyY7EBBwozI',
#     'is_local': False,
#     'name': 'Out of Reach',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83a8460bb5cd07989228e92b9b6c295119f6205e?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0Xxjyrl6Z8BtyY7EBBwozI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#        'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#        'id': '2aaLAng2L2aWD2FClzwiep',
#        'name': 'Dream Theater',
#        'type': 'artist',
#        'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sRDi0MSGOy91fHhcpXIu4'},
#      'href': 'https://api.spotify.com/v1/albums/1sRDi0MSGOy91fHhcpXIu4',
#      'id': '1sRDi0MSGOy91fHhcpXIu4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273baa61502a0635455d78eff6b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02baa61502a0635455d78eff6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851baa61502a0635455d78eff6b',
#        'width': 64}],
#      'name': 'Distance Over Time (Bonus track version)',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1sRDi0MSGOy91fHhcpXIu4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#       'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#       'id': '2aaLAng2L2aWD2FClzwiep',
#       'name': 'Dream Theater',
#       'type': 'artist',
#       'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 240626,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC1906510'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3t99aM9eXtVHNACRuLgcwy'},
#     'href': 'https://api.spotify.com/v1/tracks/3t99aM9eXtVHNACRuLgcwy',
#     'id': '3t99aM9eXtVHNACRuLgcwy',
#     'is_local': False,
#     'name': 'Viper King (Bonus track)',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d7e46df1b404ba21122651bb51eef63cbbfb7044?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3t99aM9eXtVHNACRuLgcwy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bToe6WyGvADJftreuXh2K'},
#        'href': 'https://api.spotify.com/v1/artists/2bToe6WyGvADJftreuXh2K',
#        'id': '2bToe6WyGvADJftreuXh2K',
#        'name': 'Lee Fields & The Expressions',
#        'type': 'artist',
#        'uri': 'spotify:artist:2bToe6WyGvADJftreuXh2K'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/535eEdWzIdctqDMi1LzPyG'},
#      'href': 'https://api.spotify.com/v1/albums/535eEdWzIdctqDMi1LzPyG',
#      'id': '535eEdWzIdctqDMi1LzPyG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730210afb070d48cbb1ba4aa08',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020210afb070d48cbb1ba4aa08',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510210afb070d48cbb1ba4aa08',
#        'width': 64}],
#      'name': 'Special Night',
#      'release_date': '2016-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:535eEdWzIdctqDMi1LzPyG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bToe6WyGvADJftreuXh2K'},
#       'href': 'https://api.spotify.com/v1/artists/2bToe6WyGvADJftreuXh2K',
#       'id': '2bToe6WyGvADJftreuXh2K',
#       'name': 'Lee Fields & The Expressions',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bToe6WyGvADJftreuXh2K'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204933,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ2L61600177'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5vqpqtfB307u4tRj6WCrbd'},
#     'href': 'https://api.spotify.com/v1/tracks/5vqpqtfB307u4tRj6WCrbd',
#     'id': '5vqpqtfB307u4tRj6WCrbd',
#     'is_local': False,
#     'name': 'Time (Bonus Track)',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/606bc85b28913852432a22908f1109045fbe3c0a?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5vqpqtfB307u4tRj6WCrbd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UuvaSzB0VNumArR71ReMT'},
#        'href': 'https://api.spotify.com/v1/artists/2UuvaSzB0VNumArR71ReMT',
#        'id': '2UuvaSzB0VNumArR71ReMT',
#        'name': 'Emil Rottmayer',
#        'type': 'artist',
#        'uri': 'spotify:artist:2UuvaSzB0VNumArR71ReMT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7sQMtl5XhwneVW3GukpCEv'},
#      'href': 'https://api.spotify.com/v1/albums/7sQMtl5XhwneVW3GukpCEv',
#      'id': '7sQMtl5XhwneVW3GukpCEv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733a72f0357ab2809863966dd1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023a72f0357ab2809863966dd1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513a72f0357ab2809863966dd1',
#        'width': 64}],
#      'name': 'Descend',
#      'release_date': '2018-04-06',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7sQMtl5XhwneVW3GukpCEv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UuvaSzB0VNumArR71ReMT'},
#       'href': 'https://api.spotify.com/v1/artists/2UuvaSzB0VNumArR71ReMT',
#       'id': '2UuvaSzB0VNumArR71ReMT',
#       'name': 'Emil Rottmayer',
#       'type': 'artist',
#       'uri': 'spotify:artist:2UuvaSzB0VNumArR71ReMT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 349090,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4DW1854363'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7BR6QD2GTHHF4l9eCmpMeI'},
#     'href': 'https://api.spotify.com/v1/tracks/7BR6QD2GTHHF4l9eCmpMeI',
#     'id': '7BR6QD2GTHHF4l9eCmpMeI',
#     'is_local': False,
#     'name': 'T.I.M.E (Bonus Track)',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/717a907b13866696eea9bb1f6b29658653f66fe2?cid=6f511f76a1e44dcdb8c740dc527d497d',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:7BR6QD2GTHHF4l9eCmpMeI'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%2CTime&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 12584}}

# %%
#spotify.get_artist('3TVXtAsR1Inumwj472S9r4')
